# %% [markdown]
# # import library

# %%
import pandas as pd
from matplotlib import pyplot as plt

# %% [markdown]
# # Membaca data

# %%
df = pd.read_csv("Bengaluru_House_Data.csv")
df
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# ...

# %%
df.head()
# Out:
#               area_type   availability                  location       size  \
# 0  Super built-up  Area         19-Dec  Electronic City Phase II      2 BHK
# 1            Plot  Area  Ready To Move          Chikka Tirupathi  4 Bedroom
# 2        Built-up  Area  Ready To Move               Uttarahalli      3 BHK
# 3  Super built-up  Area  Ready To Move        Lingadheeranahalli      3 BHK
# 4  Super built-up  Area  Ready To Move                  Kothanur      2 BHK
#
#    society total_sqft  bath  balcony   price
# 0  Coomee        1056   2.0      1.0   39.07
# 1  Theanmp       2600   5.0      3.0  120.00
# 2      NaN       1440   2.0      3.0   62.00
# 3  Soiewre       1521   3.0      1.0   95.00
# 4      NaN       1200   2.0      1.0   51.00

# %% [markdown]
# # Visualisasi Data

# %% [markdown]
# # Grafik Batang
# Dari grafik batang dibawah menunjukan Rumah Berbalkon dengan banyak harga

# %%
x = list(df["balcony"])
y = list(df["price"])

plt.xlabel("Balkon")
plt.ylabel("Harga")
plt.title("Grafik Batang")
plt.bar(x,y,color="red")
plt.show()

# %% [markdown]
# # Grafik pie
# Grafik dibawah menunjukan banyak type area yang tersedia

# %%
data_pie = df["area_type"].value_counts()
data_pie.head()
# Out:
# Super built-up  Area    8790
# Built-up  Area          2418
# Plot  Area              2025
# Carpet  Area              87
# Name: area_type, dtype: int64

# %%
data_pie = df["availability"].value_counts().rename_axis("area_type")
data_pie.head()
# Out:
# area_type
# Ready To Move    10581
# 18-Dec             307
# 18-May             295
# 18-Apr             271
# 18-Aug             200
# Name: availability, dtype: int64

# %%
data_pie = df["area_type"].value_counts().rename_axis("area_type").reset_index(name="id_count")
data_pie.head()
# Out:
#               area_type  id_count
# 0  Super built-up  Area      8790
# 1        Built-up  Area      2418
# 2            Plot  Area      2025
# 3          Carpet  Area        87

# %%
plt.title("Grafik Pie")
plt.pie(data_pie["id_count"],labels=data_pie["area_type"],startangle=90,autopct="%.2f%%",shadow=True,explode=(0,0,0,0.05))
plt.show()

# %% [markdown]
# # Grafik garis
# grafik dibawah menunjukan type area dengan banyak balkon

# %%
x = list(df["area_type"])
y = list(df["balcony"])
plt.title("Grafik Garis")
plt.plot(x,y)
plt.show()

# %% [markdown]
# # Kesimpulan :

# %% [markdown]
# # kesimpulan yang bisa kita ambil dari Grafik data diatas
# # Setiap grafik memiliki keunggulan dan kegunaannya masing-masing
# # dimana banyaknya data memengaruhi hasil visualisasi
# # Tidak semua data Bisa memiliki tampilan atau hasil visualisasi yang bagus
# # semakin banyak data yang berbeda maka semakin komplek juga grafiknya

# %% [markdown]
# # Sekian Terimakasih
